# %% [markdown]
# ## Algorith to identify is an image is either a dog or a cat
# - Example of cats images
#
# ![cat.4040.jpg](data:image/jpeg;base64,...)
#
# ![cat.4003.jpg](data:image/jpeg;base64,...)
#
# ![cat.4001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Example of dog images
#
# ![dog.4037.jpg](data:image/jpeg;base64,...)
#
# ![dog.4010.jpg](data:image/jpeg;base64,...)
#
# ![dog.4003.jpg](data:image/jpeg;base64,...)
